# %%
import numpy as np
import pandas as pd
import seaborn as sns
import re
from datetime import date

# %%
teis_df= pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', None)
reported_data=pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', 0)
reported_totals=pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', 1)
eco=pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', 2)
exit_notes=pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', 3)
terms_acr=pd.read_excel('../Data/TEIS Exit Data for NSS.xlsx', 4)

# %%
exit_notes.describe()
# Out:
#             Child ID  Days from I-IFSP to Exit
# count    5582.000000               5582.000000
# mean   460168.405231                504.307417
# std     17611.033346                245.392985
# min    420959.000000                180.000000
# 25%    446308.500000                308.000000
# 50%    464528.000000                454.000000
# 75%    473850.750000                670.000000
# max    492408.000000               1076.000000

# %%
exit_notes['exit_dates'] = exit_notes['Exit Note'].str.findall(r'Exit Date: \d+[/-]\d+[/-]\d+')

# %%
exit_notes['reopened'] = exit_notes['Exit Note'].str.findall(r'Reopened: \d+[/-]\d+[/-]\d+')

# %%
print(type(exit_notes))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
exit_notes['exit_dates'].dtype
# Out:
# dtype('O')

# %%
exit_notes.head(50)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
#def numOfDays(exit_dates, reopened):
    #return (reopened-exit_dates).days

# %%
for index, row in exit_notes.head(2251).iterrows():
     if(len(row.exit_dates))!=0:
        for i in range(0,len(row.exit_dates)):
            if i ==0:
                exit_notes.loc[index,'exit1']=row.exit_dates[i][len(row.exit_dates[i])-10:]
            elif i ==1:
                exit_notes.loc[index,'exit2']=row.exit_dates[i][len(row.exit_dates[i])-10:]
            elif i ==2:
                exit_notes.loc[index,'exit3']=row.exit_dates[i][len(row.exit_dates[i])-10:]
            elif i ==3:
                exit_notes.loc[index,'exit4']=row.exit_dates[i][len(row.exit_dates[i])-10:]
            elif i ==4:
                exit_notes.loc[index,'exit5']=row.exit_dates[i][len(row.exit_dates[i])-10:]

# %%
exit_notes.head(30)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
exit_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5582 entries, 0 to 5581
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   POE                       5582 non-null   object
#  1   Child ID                  5582 non-null   int64
#  2   DOB                       5582 non-null   datetime64[ns]
#  3   Notification Date         5582 non-null   datetime64[ns]
#  4   Initial Eligibility Date  5582 non-null   datetime64[ns]
#  5   Initial IFSP Date         5582 non-null   datetime64[ns]
#  6   Latest IFSP Date          5508 non-null   datetime64[ns]
#  7   Exit Reason               5582 non-null   object
#  8   Exit Date                 5582 non-null   datetime64[ns]
#  9   Days from I-IFSP to Exit  5582 non-null   int64
#  10  Exit Note                 2251 non-null   object
#  11  exit_dates                2251 non-null   object
#  12  reopened                  2251 non-null   object
# ...

# %%
for index, row in exit_notes.head(2251).iterrows():
     if(len(row.reopened))!=0:
        for i in range(0,len(row.reopened)):
            if i ==0:
                exit_notes.loc[index,'reopened1']=row.reopened[i][len(row.reopened[i])-10:]
            elif i ==1:
                exit_notes.loc[index,'reopened2']=row.reopened[i][len(row.reopened[i])-10:]
            elif i ==2:
                exit_notes.loc[index,'reopened3']=row.reopened[i][len(row.reopened[i])-10:]
            elif i ==3:
                exit_notes.loc[index,'reopened4']=row.reopened[i][len(row.reopened[i])-10:]
            elif i ==4:
                exit_notes.loc[index,'reopened5']=row.reopened[i][len(row.reopened[i])-10:]

# %%
exit_notes.head(40)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
exit_notes.DOB=pd.to_datetime(exit_notes.DOB)

# %%
exit_notes['Notification Date']=pd.to_datetime(exit_notes['Notification Date'])

# %%
exit_notes.columns
# Out:
# Index(['POE', 'Child ID', 'DOB', 'Notification Date',
#        'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP Date',
#        'Exit Reason', 'Exit Date', 'Days from I-IFSP to Exit', 'Exit Note',
#        'exit_dates', 'reopened', 'exit1', 'exit2', 'exit3', 'exit4', 'exit5',
#        'reopened1', 'reopened2', 'reopened3', 'reopened4', 'reopened5'],
#       dtype='object')

# %%
exit_notes['Initial Eligibility Date']=pd.to_datetime(exit_notes['Initial Eligibility Date'])

# %%
exit_notes['Initial IFSP Date']=pd.to_datetime(exit_notes['Initial IFSP Date'])

# %%
exit_notes['Latest IFSP Date']=pd.to_datetime(exit_notes['Latest IFSP Date'])

# %%
exit_notes['Exit Date']=pd.to_datetime(exit_notes['Exit Date'])

# %%
exit_notes.dtypes
# Out:
# POE                                 object
# Child ID                             int64
# DOB                         datetime64[ns]
# Notification Date           datetime64[ns]
# Initial Eligibility Date    datetime64[ns]
# Initial IFSP Date           datetime64[ns]
# Latest IFSP Date            datetime64[ns]
# Exit Reason                         object
# Exit Date                   datetime64[ns]
# Days from I-IFSP to Exit             int64
# Exit Note                           object
# exit_dates                          object
# reopened                            object
# exit1                               object
# exit2                               object
# exit3                               object
# exit4                               object
# exit5                               object
# reopened1                           object
# reopened2                           object
# reopened3                           object
# reopened4                           object
# ...

# %%
exit_notes['exit1']=pd.to_datetime(exit_notes['exit1'].str.replace('e: ', "").str.replace(': ', ""))

# %%
exit_notes['exit2']=pd.to_datetime(exit_notes['exit2'].str.replace(': ', "").str.replace('te', "").str.replace('e', ""))

# %%
# another way to fix the eror--
#exit_notes.exit1=pd.to_datetime(exit_notes['exit4']).str.extract(r'\d+[/-]\d+[/-]\d+')

# %%
exit_notes.exit3=pd.to_datetime(exit_notes['exit3'])

# %%
exit_notes.exit4=pd.to_datetime(exit_notes['exit4'])

# %%
exit_notes.exit5=pd.to_datetime(exit_notes['exit5'])

# %%
exit_notes.dtypes
# Out:
# POE                                 object
# Child ID                             int64
# DOB                         datetime64[ns]
# Notification Date           datetime64[ns]
# Initial Eligibility Date    datetime64[ns]
# Initial IFSP Date           datetime64[ns]
# Latest IFSP Date            datetime64[ns]
# Exit Reason                         object
# Exit Date                   datetime64[ns]
# Days from I-IFSP to Exit             int64
# Exit Note                           object
# exit_dates                          object
# reopened                            object
# exit1                       datetime64[ns]
# exit2                       datetime64[ns]
# exit3                       datetime64[ns]
# exit4                       datetime64[ns]
# exit5                       datetime64[ns]
# reopened1                           object
# reopened2                           object
# reopened3                           object
# reopened4                           object
# ...

# %%
exit_notes.reopened1=pd.to_datetime(exit_notes['reopened1'])

# %%
exit_notes.reopened2=pd.to_datetime(exit_notes['reopened2'])

# %%
exit_notes.reopened3=pd.to_datetime(exit_notes['reopened3'])

# %%
exit_notes.reopened4=pd.to_datetime(exit_notes['reopened4'])

# %%
exit_notes.reopened5=pd.to_datetime(exit_notes['reopened5'])

# %%
exit_notes.dtypes
# Out:
# POE                                 object
# Child ID                             int64
# DOB                         datetime64[ns]
# Notification Date           datetime64[ns]
# Initial Eligibility Date    datetime64[ns]
# Initial IFSP Date           datetime64[ns]
# Latest IFSP Date            datetime64[ns]
# Exit Reason                         object
# Exit Date                   datetime64[ns]
# Days from I-IFSP to Exit             int64
# Exit Note                           object
# exit_dates                          object
# reopened                            object
# exit1                       datetime64[ns]
# exit2                       datetime64[ns]
# exit3                       datetime64[ns]
# exit4                       datetime64[ns]
# exit5                       datetime64[ns]
# reopened1                   datetime64[ns]
# reopened2                   datetime64[ns]
# reopened3                   datetime64[ns]
# reopened4                   datetime64[ns]
# ...

# %%
exit_notes.head(40)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
for index, row in exit_notes.iterrows():
    print(row['exit1'], row['reopened1'])
# Out:
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2019-11-26 00:00:00 2020-04-06 00:00:00
# NaT NaT
# NaT NaT
# 2020-04-07 00:00:00 2021-02-05 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# 2018-06-17 00:00:00 2019-01-11 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# 2019-12-05 00:00:00 2020-02-28 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2020-03-09 00:00:00 2020-08-04 00:00:00
# 2019-12-10 00:00:00 2020-02-07 00:00:00
# NaT NaT
# NaT NaT
# 2019-09-27 00:00:00 2020-01-10 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2020-01-21 00:00:00 2020-08-26 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2020-03-06 00:00:00 2020-03-10 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2019-07-12 00:00:00 2020-09-15 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# NaT NaT
# 2019-07-11 00:00:00 2019-08-01 00:00:00
# NaT NaT
# NaT NaT
# 2018-10-26 00:00:00 2019-04-25 00:00:00
# NaT NaT
# NaT NaT
# NaT NaT
# ...

# %%
for index, row in exit_notes.iterrows():
    totaldays= pd.Timestamp.today()-pd.Timestamp.today()
    if (pd.notnull(row.exit1)and pd.notnull(row.reopened1)): 
        totaldays += (row.reopened1-row.exit1)
    if (pd.notnull(row.exit2)and pd.notnull(row.reopened2)):
        totaldays += (row.reopened2-row.exit2)
    if (pd.notnull(row.exit3)and pd.notnull(row.reopened3)):
        totaldays += (row.reopened3-row.exit3)
    if (pd.notnull(row.exit4)and pd.notnull(row.reopened4)):
        totaldays += (row.reopened4-row.exit4)
    if (pd.notnull(row.exit5)and pd.notnull(row.reopened5)):
        totaldays += (row.reopened5-row.exit5)
    exit_notes.loc[index,'totaldays']=totaldays

# %%
exit_notes.head(35)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
exit_notes.columns
# Out:
# Index(['POE', 'Child ID', 'DOB', 'Notification Date',
#        'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP Date',
#        'Exit Reason', 'Exit Date', 'Days from I-IFSP to Exit', 'Exit Note',
#        'exit_dates', 'reopened', 'exit1', 'exit2', 'exit3', 'exit4', 'exit5',
#        'reopened1', 'reopened2', 'reopened3', 'reopened4', 'reopened5',
#        'totaldays'],
#       dtype='object')

# %%
exit_notes['exit_notes_ttl']=(exit_notes['reopened1']-exit_notes['exit1'])+(exit_notes['reopened2']-exit_notes['exit2'])+(exit_notes['reopened3']-exit_notes['exit3'])+(exit_notes['reopened4']-exit_notes['exit4'])+(exit_notes['reopened5']-exit_notes['exit5'])

# %%
exit_notes.head(40)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
exit_notes['totaldays']=exit_notes['totaldays'].dt.days

# %%
exit_notes['actual_days']=exit_notes['Days from I-IFSP to Exit']-exit_notes['totaldays']

# %%
exit_notes.head(40)
# Out:
#    POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0   UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1   FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2   FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3   FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4   FT    469194 2017-08-31        2019-09-04               2019-10-02
# 5   UC    473474 2017-11-05        2020-04-06               2020-04-24
# 6   NW    460887 2017-07-19        2019-04-17               2019-05-22
# 7   SE    480267 2018-01-30        2020-03-20               2020-04-28
# 8   GN    469243 2019-07-26        2019-09-04               2019-10-01
# 9   FT    438070 2018-05-22        2018-06-06               2018-07-03
# 10  GN    446165 2018-06-30        2018-10-01               2018-10-19
# 11  GN    446306 2018-06-30        2018-10-02               2018-10-19
# ...

# %%
exit_notes = exit_notes.drop(columns = ['POE','DOB','Initial Eligibility Date','Notification Date','Latest IFSP Date', 'Exit Reason'])

# %%
exit_notes
# Out:
#       Child ID Initial IFSP Date  Exit Date  Days from I-IFSP to Exit  \
# 0       471738        2019-10-31 2020-09-21                       326
# 1       449030        2018-12-18 2021-03-06                       809
# 2       463311        2019-07-02 2020-07-08                       372
# 3       463313        2019-07-02 2020-07-08                       372
# 4       469194        2019-10-11 2020-08-30                       324
# ...        ...               ...        ...                       ...
# 5577    491609        2020-11-09 2021-05-17                       189
# 5578    491743        2020-11-09 2021-06-04                       207
# 5579    491879        2020-11-04 2021-05-06                       183
# 5580    492267        2020-11-24 2021-05-31                       188
# 5581    492408        2020-11-20 2021-05-20                       181
#
#                                               Exit Note exit_dates reopened  \
# ...

# %%
# exit_notes.loc[exit_notes['exit1'] <= exit_notes['Initial IFSP Date']] and exit_notes.loc[index, 'exit1'] = np.NaN

# %%
exit_notes.loc[exit_notes['exit1']<= exit_notes['Initial IFSP Date']]
# Out:
#       Child ID Initial IFSP Date  Exit Date  Days from I-IFSP to Exit  \
# 5       473474        2020-05-06 2020-11-04                       182
# 12      436339        2019-02-13 2021-04-01                       778
# 16      474102        2020-04-09 2021-05-10                       396
# 21      476958        2020-08-24 2021-05-25                       274
# 25      468728        2020-02-14 2020-08-17                       185
# ...        ...               ...        ...                       ...
# 2189    422972        2018-01-19 2020-08-11                       935
# 2196    430470        2018-03-19 2020-12-19                      1006
# 2222    435348        2018-10-10 2021-02-11                       855
# 2232    469330        2020-05-13 2021-02-18                       281
# 2243    463610        2019-08-12 2020-08-08                       362
#
#                                               Exit Note  \
# 5     **LEA county on the Transition page and demogr...
# ...

# %%
for index,row in exit_notes.iterrows():
    if row['exit1']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'exit1'] = None
    if row['exit2']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'exit2']= None
    if row['exit3']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'exit3']= None
    if row['exit4']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'exit4']= None
    if row['exit5']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'exit5']= None
    if row['reopened1']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'reopened1'] = None
    if row['reopened2']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'reopened2']= None
    if row['reopened3']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'reopened3']= None
    if row['reopened4']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'reopened4']= None
    if row['reopened5']<=row['Initial IFSP Date']:
        exit_notes.loc[index,'reopened5']= None

# %%
exit_notes.head(10)
# Out:
#    Child ID Initial IFSP Date  Exit Date  Days from I-IFSP to Exit  \
# 0    471738        2019-10-31 2020-09-21                       326
# 1    449030        2018-12-18 2021-03-06                       809
# 2    463311        2019-07-02 2020-07-08                       372
# 3    463313        2019-07-02 2020-07-08                       372
# 4    469194        2019-10-11 2020-08-30                       324
# 5    473474        2020-05-06 2020-11-04                       182
# 6    460887        2019-05-29 2020-07-18                       416
# 7    480267        2020-04-30 2021-01-19                       264
# 8    469243        2019-10-02 2021-02-11                       498
# 9    438070        2018-07-24 2021-05-21                      1032
#
#                                            Exit Note               exit_dates  \
# 0            * No Exit ECO available due to COVID-19                       []
# ...

# %%
# another way of doing making the change 
#exit_notes.exit1.mask(exit_notes.exit1 <= exit_notes['Initial IFSP Date'], np.NaN,inplace=True)
